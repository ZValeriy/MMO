# %% [markdown]
# # Зубаиров Валерий, ИУ5-24М
# ## РК №1 по курсу ММО
# ### МГТУ им. Н. Э. Баумана, Москва

# %%
import numpy as np
import pandas as pd
import seaborn as sns

import matplotlib.pyplot as plt
import matplotlib.mlab as mlab
import matplotlib
plt.style.use('ggplot')
from matplotlib.pyplot import figure

# %matplotlib inline
matplotlib.rcParams['figure.figsize'] = (12,8)

# %%
filename =  "./V.csv"

# %%
data = pd.read_csv(filename)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 9 columns):
# Serial No.           400 non-null int64
# GRE Score            400 non-null int64
# TOEFL Score          400 non-null int64
# University Rating    400 non-null int64
# SOP                  400 non-null float64
# LOR                  400 non-null float64
# CGPA                 400 non-null float64
# Research             400 non-null int64
# Chance of Admit      400 non-null float64
# dtypes: float64(4), int64(5)
# memory usage: 28.2 KB

# %%
data.describe()
# Out:
#        Serial No.   GRE Score  ...    Research  Chance of Admit
# count  400.000000  400.000000  ...  400.000000        400.000000
# mean   200.500000  316.807500  ...    0.547500          0.724350
# std    115.614301   11.473646  ...    0.498362          0.142609
# min      1.000000  290.000000  ...    0.000000          0.340000
# 25%    100.750000  308.000000  ...    0.000000          0.640000
# 50%    200.500000  317.000000  ...    1.000000          0.730000
# 75%    300.250000  325.000000  ...    1.000000          0.830000
# max    400.000000  340.000000  ...    1.000000          0.970000
#
# [8 rows x 9 columns]

# %%
data.corr()
# Out:
#                    Serial No.  GRE Score  ...  Research  Chance of Admit
# Serial No.           1.000000  -0.097526  ... -0.063138          0.042336
# GRE Score           -0.097526   1.000000  ...  0.580391          0.802610
# TOEFL Score         -0.147932   0.835977  ...  0.489858          0.791594
# University Rating   -0.169948   0.668976  ...  0.447783          0.711250
# SOP                 -0.166932   0.612831  ...  0.444029          0.675732
# LOR                 -0.088221   0.557555  ...  0.396859          0.669889
# CGPA                -0.045608   0.833060  ...  0.521654          0.873289
# Research            -0.063138   0.580391  ...  1.000000          0.553202
# Chance of Admit      0.042336   0.802610  ...  0.553202          1.000000
#
# [9 rows x 9 columns]

# %%
data.hist()
# Out:
# /usr/local/lib/python3.6/dist-packages/pandas/plotting/_matplotlib/tools.py:307: MatplotlibDeprecationWarning:
# The rowNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().rowspan.start instead.
#   layout[ax.rowNum, ax.colNum] = ax.get_visible()
# /usr/local/lib/python3.6/dist-packages/pandas/plotting/_matplotlib/tools.py:307: MatplotlibDeprecationWarning:
# The colNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().colspan.start instead.
#   layout[ax.rowNum, ax.colNum] = ax.get_visible()
# /usr/local/lib/python3.6/dist-packages/pandas/plotting/_matplotlib/tools.py:313: MatplotlibDeprecationWarning:
# The rowNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().rowspan.start instead.
#   if not layout[ax.rowNum + 1, ax.colNum]:
# ...

# %%
f,ax = plt.subplots(figsize=(18, 18))
sns.heatmap(data.corr(), annot=True, linewidths=.5, fmt= '.1f',ax=ax)
plt.show()

# %%
sns.jointplot(x='GRE Score', y='CGPA', data=data)

sns.jointplot(x='University Rating', y='TOEFL Score', data=data)

# %%
sns.boxplot(x=data["University Rating"], y=data["TOEFL Score"])

# %%
sns.jointplot(x='University Rating', y='Chance of Admit ', data=data)

# %%
sns.boxplot(x=data["University Rating"], y=data["Chance of Admit "])

# %%
sns.boxplot(x=data["GRE Score"])

# %%
fig, ax = plt.subplots(figsize=(10,10)) 
sns.distplot(data['Chance of Admit '])

# %%
fig, ax = plt.subplots(figsize=(10,10)) 
sns.distplot(data['TOEFL Score'])

# %%
sns.jointplot(x='TOEFL Score', y='Chance of Admit ', data=data)

# %%
sns.jointplot(x='CGPA', y='Chance of Admit ', data=data)

# %%
sns.jointplot(x='GRE Score', y='Chance of Admit ', data=data)

# %%
sns.scatterplot(x='TOEFL Score', y='CGPA', data=data, hue='Chance of Admit ')

# %%
sns.violinplot(x=data["TOEFL Score"])

# %% [markdown]
# В данном датасете целевой признак - Chance of Admit.
# Видно, что на него влияют другие признаки - University Rating, TOEFL Score, GRE Score, CGPA, LOR, SOP.
# Часть этих признаков имеет довольно большую корреляцию между собой, поэтому много признаков можно удалить без потери точности предсказания целевого признака. Можно построить модель линейной регрессии, она будет достаточно точна
